# %% [markdown]
# # Week 4

# %% [markdown]
# ### Quiz 2: Tuesday, February 10, 2026
#
# Quiz 2 will be given during the class on Tuesday. Here is a [sample quiz](../../_static/quizzes/quiz3_sample.pdf).
# If you have any questions about the sample quiz, I will go over them before the real quiz on Tuesday.
#
# <br/>
#
# **What is covered:**
#
# - List operations: `len`, `sum`, `min`, `max`, `index`.
# - Code comments and docstrings.
# - Lists comprehensions.
# - Matplotlib plots.

# %% [markdown]
# ## Python
#
# - [Numpy array basics](../../python_tools/numpy_arrays.ipynb).
# - [Multidimensional numpy arrays](../../python_tools/numpy_multidim.ipynb).
# - [Boolean numpy arrays](../../python_tools/numpy_boolean.ipynb).
# - [Image processing](../../python_tools/image_processing/image_processing.ipynb).
