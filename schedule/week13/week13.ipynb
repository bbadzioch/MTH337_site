# %% [markdown]
# # Week 13
#
# % [**Notebook from this week**](week13_notebook.ipynb)
# % [**Weekly Digest 9**](../../digests/digest_9.md)
#
# <br/>

# %% [markdown]
# ## Quiz 12: Tuesday, April 21, 2026
#
# Quiz 12 will be given during the class on Tuesday. Here is a [sample quiz](../../_static/quizzes/quiz12_sample.pdf).
# If you have any questions about the sample quiz, I will go over them before the real quiz on Tuesday.
#
# <br/>
#
# **What is covered:**
#
# - regular expressions

# %% [markdown]
# ## Working with sound
#
# - Sample audio file:
#
#     ```
#     https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/schedule/week13/sample.wav
#     ```
#
# - Score:
#
#     ```{code} python
#     score = {"r": [[495, 0.17], [495, 0.17], [0, 0.17], [495, 0.17], [0, 0.17], [393, 0.17], [495, 0.35],
#                    [588, 0.35], [0, 0.35], [294, 0.35], [0, 0.35], [393, 0.35], [0, 0.17], [294, 0.35],
#                    [0, 0.17], [247, 0.17], [0, 0.35], [660, 0.35], [741, 0.35], [699, 0.17], [660, 0.35],
#                    [588, 0.23], [988, 0.23], [1176, 0.23], [1320, 0.35], [1047, 0.17], [1176, 0.17],
#                    [0, 0.17], [988, 0.35], [784, 0.17], [880, 0.17], [741, 0.35], [0, 0.17]],
#             "l":  [[109, 0.17], [109, 0.17], [0, 0.17], [109, 0.17], [0, 0.17], [109, 0.17], [109, 0.35],
#                    [147, 0.35], [0, 0.35], [73, 0.35], [0, 0.35], [147, 0.35], [0, 0.17], [123, 0.35], [0, 0.17],
#                    [97, 0.17], [0, 0.35], [130, 0.35], [147, 0.35], [138, 0.17], [130, 0.35], [123, 0.23],
#                    [196, 0.23], [247, 0.23], [258, 0.35], [220, 0.17], [247, 0.17], [0, 0.17], [196, 0.35],
#                    [165, 0.17], [184, 0.17], [147, 0.35], [0, 0.17]]
#             }
#     ```

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Exercise 1.
#
#  Write a function `get_bounces()` that takes as an argument a numpy array representing the sound of a bouncing ball, and returns
#  a list of the times of bounces. Check the results using the following files:
#
#  <br/>
#
#
#  - [pingpong.wav](https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/schedule/week13/pingpong.wav) - a sound of a bouncing pingpong ball
#
#     ```
#     https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/schedule/week13/pingpong.wav
#     ```
#
# - [basketball.wav](https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/schedule/week13/basketball.wav) - a sound of a bouncing basketball
#
#     ```
#     https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/schedule/week13/basketball.wav
#     ```
#
# - [rubberball.wav](https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/schedule/week13/basketball.wav) - a sound of a bouncing rubber ball
#
#     ```
#     https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/schedule/week13/rubberball.wav
#     ```

# %% [markdown]
# <br/><br/>
