# %% [markdown]
# # Week 6
#
# % [**Notebook from this week**](week5_notebook.ipynb)
#
# <br/>

# %% [markdown]
# ### Quiz 5: Tuesday, February 24, 2026
#
# Quiz 5 will be given during the class on Tuesday. Here is a [sample quiz](../../_static/quizzes/quiz5_sample.pdf).
# If you have any questions about the sample quiz, I will go over them before the real quiz on Tuesday.
#
# <br/>
#
# **What is covered:**
#
# - Numpy arrays: shape, mean, median.
# - Boolean numpy arrays.

# %% [markdown]
# ## Python
#
# - [Matpotlib subplots](../../python_tools/matplotlib_subplots.ipynb).
# - [Networkx](https://networkx.org/documentation/stable/index.html)

# %% [markdown]
# ## Image noise review

# %% [markdown]
# [circuit.png](https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/schedule/week4/circuit.png)
#
# ```
# https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/schedule/week4/circuit.png
# ```

# %%
def salt_noise(img, p):
    img = img.copy()
    rng = np.random.default_rng()
    selection = (rng.random(img.shape) < p)
    img[selection] = 1
    return img

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Exercise 1
#
# Write a function `random_graph(n, p)` that returns the adjancency matrix of a random graph with `n` vertices, where each edge is included with probability `p`.

# %% [markdown]
# ### Exercise 2
#
# Write a function `plot_epidemic(adj, status, title)` that takes an its arguments an $n\times n$ adjacency matrix `adj`, a 1-dimensional array `status` that lists the status of each node (either 0, 1, or 2) and a string `title`. The function should plot the graph represented by `adj`, selecting colors of nodes based on the values of `status`: 0 = `"green"`, 1 = `"red"`, 2 = `"gold"`. The string `title ` should be used for the title of the plot.

# %% [markdown]
# ### Exercise 3
#
# Write a function `epidemic_step(adj, status, pr, pi)` with the following arguments:
# - `adj` - the adjacency matrix of a graph.
# - `status` - a 1-dimensional array listing the status of each node of the graph (0 = healthy, 1 = infected, 2 = recovered).
# - `pi` - a number between 0 and 1 with probability of a node getting infected by another node.
# - `pr` - a number between 0 and 1 with probability that an infected node recovers from the infection.
#
# The function should return an array `new_status` computed as follows:
# - For each infected node, check all its neighbors. If a neighbor is healthy, it will become infected with probability `pi`.
# - Each infected node will recover from the infections with probability `pr`.

# %% [markdown]
# ### Exercise 4
#
# Write a function `simulate_epidemic(adj, status, pr, pi, num_steps)` with the following arguments:
# - `adj` - the adjacency matrix of a graph.
# - `status` - a 1-dimensional array listing the initial status of each node of the graph (0 = healthy, 1 = infected, or 2 = recovered).
# - `pi` - a number between 0 and 1 with probability of a node getting infected by another node.
# - `pr` - a number between 0 and 1 with probability that an infected node recovers from the infection.
# - `num_steps` - integer with the number of epidemic steps to compute.
#
# The function should return a 2-dimensional array `epidemic` computed as follows:
# - The first row of `epidemic` is the same as `status`.
# - The second row is the status after one epidemic step.
# - The third row is the status after two epidemic steps, and so on.
# The number of rows should be equal to  `num_steps`.

# %% [markdown]
# <br/><br/>
