# %% [markdown]
# # Week 14
#
# [**Notebook from this week**](week14_notebook.ipynb)
#
# <br/>

# %% [markdown]
# ## Quiz
#
# There will be no more quizzes in this course.
#
# <br/>

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Exercise 1.
#
#  Write a function `get_bounces()` that takes as an argument a numpy array representing the sound of a bouncing ball, and returns
#  a list of indexes of bounces. Check the results using the following files:
#
#
#  - [pingpong.wav](https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/schedule/week14/pingpong.wav) - a sound of a bouncing pingpong ball
#
#     ```
#     https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/schedule/week14/pingpong.wav
#     ```
#
# - [basketball.wav](https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/schedule/week14/basketball.wav) - a sound of a bouncing basketball
#
#     ```
#     https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/schedule/week14/basketball.wav
#     ```
#
# - [rubberball.wav](https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/schedule/week14/basketball.wav) - a sound of a bouncing rubber ball
#
#     ```
#     https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/schedule/week14/rubberball.wav
#     ```

# %% [markdown]
# <br/><br/>
