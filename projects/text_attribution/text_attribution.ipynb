# %% [markdown]
# # Text attribution

# %% [markdown]
# The goal of this project is to experiment if it is possible to identify the author of some text by comparing it to texts whose authors are already known. In the project we will be using two collections of texts:
#
# - `training_texts` that we will use as reference texts whose aurthors we already know.
# - `test_texts` whose authors we will try to predict by comparing them to `training_texts`.
#
# Each of these collections is given below as a dictionary. Dictionary keys identify authors and shortened titles of texts,  values are urls of text files.

# %%
training_urls = {"addams_democracy": "https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/text_attribution/books/addams_democracy.txt",
                  "emerson_conduct": "https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/text_attribution/books/emerson_conduct.txt",
                  "fuller_europe": "https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/text_attribution/books/fuller_europe.txt",
                  "muir_sierra": "https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/text_attribution/books/muir_sierra.txt",
                  "thoreau_rivers": "https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/text_attribution/books/thoreau_rivers.txt"
                  }


test_urls = {"addams_hull_house": "https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/text_attribution/books/addams_hull_house.txt",
              "addams_youth": "https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/text_attribution/books/addams_youth.txt",
              "emerson_nature": "https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/text_attribution/books/emerson_nature.txt",
              "emerson_representative_men": "https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/text_attribution/books/emerson_representative_men.txt",
              "fuller_summer": "https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/text_attribution/books/fuller_summer.txt",
              "fuller_woman": "https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/text_attribution/books/fuller_woman.txt",
              "muir_sierra": "https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/text_attribution/books/muir_sierra.txt",
              "muir_walk": "https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/text_attribution/books/muir_walk.txt",
              "thoreau_walden": "https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/text_attribution/books/thoreau_walden.txt",
              "thoreau_yankee": "https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/text_attribution/books/thoreau_yankee.txt"
              }

# %% [markdown]
# ## Project
#
# - Implement functions that add random-valued impulse noise and salt-and-pepper noise to grayscale images. Illustrate
#   the effect of these types of noise on some example images.
#
# - Implement a median  and mean filters. Apply there filters to clean images and observe the effects there filters have
#   for various filter window sizes.
#
# - Apply the filters to images corrupted by various amounts of impulse noise and salt-and-pepper noise. How well do these filters perform?
#   Which filter performs better for which type of noise? Illustrate your results with example images.
#
# - Are there ways to improve the performance of these filters? If so, implement these improvements, illustrate  the results
#   and discuss them.

# %% [markdown]
# ## Sample images
#
# Below are links to black and white photos that you can use in your work.
#
#
# - [book.jpg](https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/book.jpg)
#
#     ```
#     https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/book.jpg
#     ```
#
# - [child.jpg](https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/child.jpg)
#
#     ```
#     https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/child.jpg
#     ```
#
# - [facade.jpg](https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/facade.jpg)
#
#     ```
#     https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/facade.jpg
#     ```
#
# - [man.jpg](https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/man.jpg)
#
#     ```
#     https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/man.jpg
#     ```
#
# - [musicians.jpg](https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/musicians.jpg)
#
#     ```
#     https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/musicians.jpg
#     ```
#
# - [signs.jpg](https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/signs.jpg)
#
#     ```
#     https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/signs.jpg
#     ```
#
# - [times-sq.jpg](https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/times-sq.jpg)
#
#     ```
#     https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/times-sq.jpg
#     ```

# %% [markdown]
# ## Extra credit
#
# This part is optional. Below are links to four photos taken at various places on campus, obscured by salt and pepper noise. For extra credit, reduce noise in these images, find locations where the photos were taken, take selfies at the same locations, and include them in your report. If you succesfully complete this part, you grade for this report will get increased to the next higher letter grade: from A to A+, from  A- to A etc.
#
# - [ubnoisy1.png](https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/ubnoisy1.png)
# ```
# https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/ubnoisy1.png
# ```
#
# - [ubnoisy2.png](https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/ubnoisy2.png)
# ```
# https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/ubnoisy2.png
# ```
#
# - [ubnoisy3.png](https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/ubnoisy3.png)
# ```
# https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/ubnoisy3.png
# ```
#
# - [ubnoisy4.png](https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/ubnoisy4.png)
# ```
# https://cdn.jsdelivr.net/gh/bbadzioch/mth337_site@main/projects/denoising/images/ubnoisy4.png
# ```
#
# ::::{note}
# **1.** To qualify for the extra credit your report must include both code producing images with noise removed to the extent that they are recognizable, and your own photos.
#
# <br/>
#
# **2.** To include your photos in the report do the following:
#
# * Place the files with your own photos in the folder with your report notebook.
#
# * For each photo create a code cell in your notebook. In this code cell enter the following code, replacing "my_photo.png" with the name of your photo file:
#
# :::python
# from IPython.display import Image
# Image("my_photo.png")
# :::
#
#  When you execute this cell, the photo should be displayed. Once you embed all photos in this way, you can submit the notebook file.
#
# <br/>
#
#  **3.** Please make sure that files with your own photos are not large (preferably under 1 MB). Otherwise the notebook file will be very big.
# ::::
